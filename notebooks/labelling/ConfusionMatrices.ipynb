# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

import pandas as pd

sys.path.append('../..')

from data import constants
#from data import evaluation
from data.evaluation import plot_cm_grid 

labels=["Acute", "Chronic", "Policy & Legal", "Technology & Market", "Reputation"]
export_path = "/Users/david/Nextcloud/Dokumente/Education/Uni Bern/Master Thesis/Analyzing Financial Climate Disclosures with NLP/Thesis/figures"

# %%
svm_mcm_old = [
    [[5,2],[16,28186]],
    [[0,0],[7,28202]],
    [[3,0],[17, 28189]],
    [[0,0],[12, 28197]],
    [[2,2],[5,28200]]
]
svm_mcm = [
    [[9, 27], [12, 28161]], 
    [[0, 3], [7, 28199]], 
    [[7, 20], [13, 28169]], 
    [[0, 3], [12, 28194]], 
    [[1, 6], [6, 28196]]
]
svm_fig = plot_cm_grid(svm_mcm, labels, ncols=2)
svm_fig.savefig(os.path.join(export_path, "mcm_svm.pdf"))

# %%
distil_mcm = [
    [[14,19],[7,28169]],
    [[7,28193],[0,9]],
    [[10,42],[10, 28147]],
    [[0,327],[12, 27870]],
    [[0,276],[7,27926]]
]
distil_fig = plot_cm_grid(distil_mcm, labels, ncols=2)
distil_fig.savefig(os.path.join(export_path, "mcm_distil.pdf"))

# %%
twostage_mcm = [
    [[17,35],[4,28153]],
    [[1,6],[6,28196]],
    [[12,43],[8, 28146]],
    [[1,13],[11, 28184]],
    [[2,18],[5,28184]]
]
twostage_fig = plot_cm_grid(twostage_mcm, labels, ncols=2)
twostage_fig.savefig(os.path.join(export_path, "mcm_2stage.pdf"))
